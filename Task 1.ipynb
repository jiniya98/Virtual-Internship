# %% [markdown]
# # Section 1 - Setup

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("samplesalesdata.csv")
df
# Out:
#       Unnamed: 0                        transaction_id            timestamp  \
# 0              0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1              1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2              2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3              3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4              4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# ...          ...                                   ...                  ...
# 7824        7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825        7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826        7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827        7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828        7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
# ...

# %% [markdown]
# ## Section 2 - Data loading

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df
# Out:
#                             transaction_id            timestamp  \
# 0     a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1     931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2     ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3     157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4     a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# ...                                    ...                  ...
# 7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
#                                 product_id           category customer_type  \
# 0     3bc6c1ea-0198-46de-9ffd-514ae3338713              fruit          gold
# ...

# %%
df.head()
# Out:
#                          transaction_id            timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
df.head(10)
# Out:
#                          transaction_id            timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# 5  b5b3c8b9-f496-484d-aa30-4f2efb5ed56c  2022-03-07 17:59:47
# 6  4997b1ae-f5aa-4b9f-8fc8-22ad8f19837c  2022-03-07 19:36:57
# 7  bfffee68-0736-42af-bd3e-4ca77541b0d6  2022-03-07 19:03:20
# 8  ce50e984-90cd-4b47-8537-3a4e32e6d314  2022-03-07 11:34:32
# 9  f0700cc9-e6f5-4b9a-add4-05e64b4f495b  2022-03-07 09:20:12
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# ...

# %%
df.tail()
# Out:
#                             transaction_id            timestamp  \
# 7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
#                                 product_id           category customer_type  \
# 7824  bc6187a9-d508-482b-9ca6-590d1cc7524f  cleaning products         basic
# 7825  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products      standard
# 7826  a9325c1a-2715-41df-b7f4-3078fa5ecd97  cleaning products         basic
# 7827  707e4237-191c-4cc9-85af-383a6c1cb2ab  cleaning products         basic
# 7828  d6ccd088-11be-4c25-aa1f-ea87c01a04db  cleaning products    non-member
#
#       unit_price  quantity  total payment_type
# 7824       14.19         2  28.38     e-wallet
# ...

# %%
df.tail(10)
# Out:
#                             transaction_id            timestamp  \
# 7819  abad87e6-5424-40cb-832d-afe5195fc3f2  2022-03-07 13:20:19
# 7820  731ab8a0-4943-4bb0-b3f4-adf97d14b210  2022-03-01 19:09:20
# 7821  a8109d22-e192-41d4-911d-84c772a68013  2022-03-02 10:42:44
# 7822  6857feab-f2b1-4de7-bd4e-14a838591411  2022-03-04 11:06:33
# 7823  60524862-cd12-47e8-aaa6-9a15e3f2c74d  2022-03-07 12:44:43
# 7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
# 7828  afd70b4f-ee21-402d-8d8f-0d9e13c2bea6  2022-03-06 13:50:36
#
#                                 product_id           category customer_type  \
# 7819  f4a73cc3-b383-4650-bfa5-970bdcadc737  cleaning products       premium
# 7820  a9325c1a-2715-41df-b7f4-3078fa5ecd97  cleaning products          gold
# ...

# %% [markdown]
# ## Section-3 Descriptive statistics

# %%
df.isnull()
# Out:
#       transaction_id  timestamp  product_id  category  customer_type  \
# 0              False      False       False     False          False
# 1              False      False       False     False          False
# 2              False      False       False     False          False
# 3              False      False       False     False          False
# 4              False      False       False     False          False
# ...              ...        ...         ...       ...            ...
# 7824           False      False       False     False          False
# 7825           False      False       False     False          False
# 7826           False      False       False     False          False
# 7827           False      False       False     False          False
# 7828           False      False       False     False          False
#
#       unit_price  quantity  total  payment_type
# 0          False     False  False         False
# ...

# %%
df.isnull().sum()
# Out:
# transaction_id    0
# timestamp         0
# product_id        0
# category          0
# customer_type     0
# unit_price        0
# quantity          0
# total             0
# payment_type      0
# dtype: int64

# %% [markdown]
# ###### Result: there is no null values in the given data set

# %%
df.columns # For getting column name's
# Out:
# Index(['transaction_id', 'timestamp', 'product_id', 'category',
#        'customer_type', 'unit_price', 'quantity', 'total', 'payment_type'],
#       dtype='object')

# %% [markdown]
# ### Mean

# %%
df.mean()
# Out:
# unit_price     7.819480
# quantity       2.501597
# total         19.709905
# dtype: float64

# %%
df.describe()
# Out:
#         unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000
# mean      7.819480     2.501597    19.709905
# std       5.388088     1.122722    17.446680
# min       0.190000     1.000000     0.190000
# 25%       3.990000     1.000000     6.570000
# 50%       7.190000     3.000000    14.970000
# 75%      11.190000     4.000000    28.470000
# max      23.990000     4.000000    95.960000

# %% [markdown]
# ### Median

# %%
df.median()
# Out:
# unit_price     7.19
# quantity       3.00
# total         14.97
# dtype: float64

# %% [markdown]
# ### count()

# %%
df.count()
# Out:
# transaction_id    7829
# timestamp         7829
# product_id        7829
# category          7829
# customer_type     7829
# unit_price        7829
# quantity          7829
# total             7829
# payment_type      7829
# dtype: int64

# %%
df.describe()
# Out:
#         unit_price     quantity        total
# count  7829.000000  7829.000000  7829.000000
# mean      7.819480     2.501597    19.709905
# std       5.388088     1.122722    17.446680
# min       0.190000     1.000000     0.190000
# 25%       3.990000     1.000000     6.570000
# 50%       7.190000     3.000000    14.970000
# 75%      11.190000     4.000000    28.470000
# max      23.990000     4.000000    95.960000

# %% [markdown]
# # Section 4 - Visualisation

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def plot_continuous_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8):
  _ = sns.displot(data, x=column, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

def get_unique_values(data, column):
    num_unique_values = len(data[column].unique())
    value_counts = data[column].value_counts()
    print(f"Column: {column} has {num_unique_values} unique values\n")
    print(value_counts)

def plot_categorical_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8, aspect: int = 2):
    sns.catplot(data=data, x=column, kind='count', height=height, aspect=aspect).set(title=f'Distribution of {column}');

def correlation_plot(data: pd.DataFrame = None):
    corr = df.corr()
    heat=corr.style.background_gradient(cmap='coolwarm')
    return heat

# %%
plot_continuous_distribution(data=df, column='category', height=5)

# %%
get_unique_values(df,'transaction_id')
# Out:
# Column: transaction_id has 7829 unique values
#
# a1c82654-c52c-45b3-8ce8-4c2a1efe63ed    1
# 6532e258-95fd-4eb5-8c67-2bfb879a8fec    1
# 6fce2af3-47a0-4755-99c9-0cefb5ab6f41    1
# 6476e388-3990-471f-b415-3ee59ae18832    1
# 10afe89b-c45b-49a2-b0be-dec89a4c3f80    1
#                                        ..
# a9abe5ac-99d5-4d8b-bbbd-c2a207642849    1
# 6b0b23e8-412b-4665-8cc4-3e37f0d9e195    1
# 711a4162-1985-4f5a-94ca-137cfacaeadf    1
# 7d1e9010-dbaf-4770-a467-f31477910f7a    1
# afd70b4f-ee21-402d-8d8f-0d9e13c2bea6    1
# Name: transaction_id, Length: 7829, dtype: int64

# %%
plot_categorical_distribution(df,'payment_type', height=6)
plt.show()

# %%
plot_categorical_distribution(df,'quantity', height=6)
plt.show()

# %%
plot_categorical_distribution(df,'total', height=6)
plt.show()

# %%
plot_categorical_distribution(df,'product_id', height=6)
plt.show()

# %% [markdown]
# ### correlation plot

# %%
correlation_plot(df)
# Out:
# <style type="text/css">
# #T_37930_row0_col0, #T_37930_row1_col1, #T_37930_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_37930_row0_col1, #T_37930_row1_col0, #T_37930_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_37930_row0_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_37930_row2_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_37930_row2_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# </style>
# <table id="T_37930">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37930_level0_col0" class="col_heading level0 col0" >unit_price</th>
#       <th id="T_37930_level0_col1" class="col_heading level0 col1" >quantity</th>
#       <th id="T_37930_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37930_level0_row0" class="row_heading level0 row0" >unit_price</th>
# ...

# %% [markdown]
# ## Section 5 - Summary

# %%
## Section 5 - Summary
We have completed an initial exploratory data analysis on the sample of data provided. We should now have a solid understanding of the data.

The client wants to know

"How to better stock the items that they sell"
From this dataset, it is impossible to answer that question. In order to make the next step on this project with the client, it is clear that:

We need more rows of data. The current sample is only from 1 store and 1 week worth of data
We need to frame the specific problem statement that we want to solve. The current business problem is too broad, we should narrow down the focus in order to deliver a valuable end product
We need more features. Based on the problem statement that we move forward with, we need more columns (features) that may help us to understand the outcome that we're solving for
